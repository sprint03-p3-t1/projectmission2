# %%
import subprocess
import json
import os
import re
import pandas as pd
from typing import Dict, List, Optional, Tuple

# hwp5txt 절대 경로
HWP5TXT_PATH = "/home/spai0323/myenv/bin/hwp5txt"

def extract_hwp_text_advanced(hwp_path):
    """hwp5txt로 HWP 텍스트 추출 - 다양한 옵션 시도"""
    try:
        # 기본 추출 시도
        result = subprocess.run(
            [HWP5TXT_PATH, hwp_path],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            check=True
        )
        return result.stdout
    except subprocess.CalledProcessError as e:
        print(f"[실패] {hwp_path} : {e.stderr}")
        return None

def extract_hwp_structured(hwp_path):
    """hwp5 라이브러리로 구조화된 데이터 추출 시도"""
    try:
        # hwp5 라이브러리가 있다면 구조화된 추출 시도
        result = subprocess.run(
            ["hwp5html", hwp_path],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )
        if result.returncode == 0:
            return result.stdout, "html"
    except:
        pass
    
    # 일반 텍스트 추출
    text = extract_hwp_text_advanced(hwp_path)
    return text, "text" if text else None

def detect_table_patterns(text: str) -> List[Tuple[int, int, str]]:
    """다양한 표 패턴 감지"""
    table_patterns = []
    lines = text.split('\n')
    
    # 패턴 1: 연속된 탭으로 구분된 행들
    tab_table_start = None
    for i, line in enumerate(lines):
        if '\t' in line and len(line.split('\t')) >= 2:
            if tab_table_start is None:
                tab_table_start = i
        else:
            if tab_table_start is not None:
                if i - tab_table_start >= 2:  # 최소 2행 이상
                    table_patterns.append((tab_table_start, i, 'tab_separated'))
                tab_table_start = None
    
    # 마지막 표가 파일 끝까지 이어지는 경우
    if tab_table_start is not None and len(lines) - tab_table_start >= 2:
        table_patterns.append((tab_table_start, len(lines), 'tab_separated'))
    
    # 패턴 2: 공백으로 정렬된 표
    aligned_table_start = None
    for i, line in enumerate(lines):
        # 3개 이상의 연속 공백으로 구분된 컬럼이 있는 행
        if re.search(r'\S+\s{3,}\S+\s{3,}\S+', line):
            if aligned_table_start is None:
                aligned_table_start = i
        else:
            if aligned_table_start is not None:
                if i - aligned_table_start >= 2:
                    table_patterns.append((aligned_table_start, i, 'space_aligned'))
                aligned_table_start = None
    
    # 패턴 3: 특정 키워드로 시작하는 표
    table_keywords = ['번호', '구분', '항목', '내용', '날짜', '금액', '수량']
    for i, line in enumerate(lines):
        line_clean = line.strip()
        if any(keyword in line_clean for keyword in table_keywords):
            # 다음 몇 줄이 표 데이터인지 확인
            table_end = i + 1
            while table_end < len(lines) and (lines[table_end].strip() and 
                  ('\t' in lines[table_end] or re.search(r'\S+\s{2,}\S+', lines[table_end]))):
                table_end += 1
            if table_end - i >= 2:
                table_patterns.append((i, table_end, 'keyword_table'))
    
    return table_patterns

def extract_table_data(lines: List[str], start: int, end: int, pattern_type: str) -> List[List[str]]:
    """표 데이터 추출 및 정리"""
    table_data = []
    
    for i in range(start, end):
        line = lines[i].strip()
        if not line:
            continue
            
        if pattern_type == 'tab_separated':
            row = [cell.strip() for cell in line.split('\t')]
        elif pattern_type == 'space_aligned':
            # 3개 이상의 연속 공백으로 분할
            row = [cell.strip() for cell in re.split(r'\s{3,}', line) if cell.strip()]
        elif pattern_type == 'keyword_table':
            # 탭이 있으면 탭으로, 없으면 공백으로 분할
            if '\t' in line:
                row = [cell.strip() for cell in line.split('\t')]
            else:
                row = [cell.strip() for cell in re.split(r'\s{2,}', line) if cell.strip()]
        else:
            row = [line]
        
        if row and any(cell for cell in row):  # 빈 행 제외
            table_data.append(row)
    
    return table_data

def normalize_table(table_data: List[List[str]]) -> List[List[str]]:
    """표 데이터 정규화 (컬럼 수 맞추기)"""
    if not table_data:
        return table_data
    
    max_cols = max(len(row) for row in table_data)
    
    normalized = []
    for row in table_data:
        # 부족한 컬럼은 빈 문자열로 채움
        normalized_row = row + [''] * (max_cols - len(row))
        normalized.append(normalized_row)
    
    return normalized

def parse_text_and_tables_improved(text: str) -> Dict:
    """개선된 본문과 표 파싱"""
    lines = text.split('\n')
    parsed = {"paragraphs": [], "tables": []}
    
    # 표 패턴 감지
    table_patterns = detect_table_patterns(text)
    
    # 표가 아닌 텍스트 라인들을 추적
    table_lines = set()
    for start, end, _ in table_patterns:
        table_lines.update(range(start, end))
    
    # 표 데이터 추출
    for i, (start, end, pattern_type) in enumerate(table_patterns):
        table_data = extract_table_data(lines, start, end, pattern_type)
        if table_data:
            normalized_table = normalize_table(table_data)
            table_info = {
                "table_id": i + 1,
                "pattern_type": pattern_type,
                "start_line": start,
                "end_line": end,
                "headers": normalized_table[0] if normalized_table else [],
                "data": normalized_table[1:] if len(normalized_table) > 1 else [],
                "raw_data": normalized_table
            }
            parsed["tables"].append(table_info)
    
    # 표가 아닌 텍스트를 단락으로 수집
    current_paragraph = []
    for i, line in enumerate(lines):
        if i not in table_lines:
            line = line.strip()
            if line:
                current_paragraph.append(line)
            else:
                if current_paragraph:
                    parsed["paragraphs"].append(' '.join(current_paragraph))
                    current_paragraph = []
    
    # 마지막 단락 처리
    if current_paragraph:
        parsed["paragraphs"].append(' '.join(current_paragraph))
    
    return parsed

def export_tables_to_csv(tables: List[Dict], output_folder: str, base_filename: str):
    """표를 개별 CSV 파일로 저장"""
    csv_folder = os.path.join(output_folder, "csv_tables")
    os.makedirs(csv_folder, exist_ok=True)
    
    for table in tables:
        if table["raw_data"]:
            table_filename = f"{base_filename}_table_{table['table_id']}.csv"
            csv_path = os.path.join(csv_folder, table_filename)
            
            # pandas로 CSV 저장
            df = pd.DataFrame(table["raw_data"])
            df.to_csv(csv_path, index=False, header=False, encoding='utf-8-sig')
            print(f"  표 {table['table_id']} -> {table_filename}")

def hwp_folder_to_json_improved(raw_folder: str, processed_folder: str):
    """개선된 HWP to JSON 변환"""
    json_output_folder = os.path.join(processed_folder, "json_output")
    os.makedirs(json_output_folder, exist_ok=True)
    
    hwp_files = [f for f in os.listdir(raw_folder) if f.endswith(".hwp")]
    
    summary = {
        "total_files": len(hwp_files),
        "processed_files": 0,
        "failed_files": 0,
        "total_tables_found": 0,
        "files_with_tables": 0
    }
    
    for hwp_file in hwp_files:
        hwp_path = os.path.join(raw_folder, hwp_file)
        print(f"처리 중: {hwp_file}")
        
        # 텍스트 추출
        result = extract_hwp_structured(hwp_path)
        if result[0] is None:
            summary["failed_files"] += 1
            continue
        
        text, format_type = result
        
        # 개선된 파싱
        parsed = parse_text_and_tables_improved(text)
        
        # 데이터 구성
        data = {
            "filename": hwp_file,
            "format_type": format_type,
            "extraction_summary": {
                "total_paragraphs": len(parsed["paragraphs"]),
                "total_tables": len(parsed["tables"]),
                "table_types": [t["pattern_type"] for t in parsed["tables"]]
            },
            "content": parsed
        }
        
        # JSON 저장
        json_filename = os.path.splitext(hwp_file)[0] + ".json"
        json_path = os.path.join(json_output_folder, json_filename)
        with open(json_path, "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
        
        # 표가 있는 경우 CSV로도 저장
        if parsed["tables"]:
            base_filename = os.path.splitext(hwp_file)[0]
            export_tables_to_csv(parsed["tables"], processed_folder, base_filename)
            summary["files_with_tables"] += 1
            summary["total_tables_found"] += len(parsed["tables"])
        
        summary["processed_files"] += 1
        print(f"  완료: {len(parsed['paragraphs'])}개 단락, {len(parsed['tables'])}개 표")
    
    # 요약 정보 저장
    summary_path = os.path.join(processed_folder, "processing_summary.json")
    with open(summary_path, "w", encoding="utf-8") as f:
        json.dump(summary, f, ensure_ascii=False, indent=2)
    
    print(f"\n=== 처리 완료 ===")
    print(f"총 파일: {summary['total_files']}")
    print(f"성공: {summary['processed_files']}")
    print(f"실패: {summary['failed_files']}")
    print(f"표가 포함된 파일: {summary['files_with_tables']}")
    print(f"총 표 개수: {summary['total_tables_found']}")

# 사용 예시
if __name__ == "__main__":
    raw_folder = "../data/raw/files""
    processed_folder = "../data/processed"

    # pandas 설치 확인
    try:
        import pandas as pd
        print("pandas가 설치되어 있습니다.")
    except ImportError:
        print("pandas를 설치해주세요: pip install pandas")
        exit(1)
    
    hwp_folder_to_json_improved(raw_folder, processed_folder)
    print("모든 HWP 파일이 처리되었습니다.")
    print("- JSON: data/processed/json_output/")
    print("- CSV 표: data/processed/csv_tables/")
    print("- 요약: data/processed/processing_summary.json")
# Out:
# pandas가 설치되어 있습니다.
# 처리 중: 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구.hwp
#   표 1 -> 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구_table_1.csv
#   표 2 -> 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구_table_2.csv
#   표 3 -> 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구_table_3.csv
#   표 4 -> 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구_table_4.csv
#   표 5 -> 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구_table_5.csv
#   표 6 -> 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구_table_6.csv
#   완료: 307개 단락, 6개 표
# 처리 중: 케빈랩 주식회사_평택시 강소형 스마트시티 AI 기반의 영상감시 시스템 .hwp
#   표 1 -> 케빈랩 주식회사_평택시 강소형 스마트시티 AI 기반의 영상감시 시스템 _table_1.csv
#   표 2 -> 케빈랩 주식회사_평택시 강소형 스마트시티 AI 기반의 영상감시 시스템 _table_2.csv
#   완료: 302개 단락, 2개 표
# 처리 중: 수협중앙회_수협중앙회 수산물사이버직매장 시스템 재구축 ISMP 수립 입.hwp
#   표 1 -> 수협중앙회_수협중앙회 수산물사이버직매장 시스템 재구축 ISMP 수립 입_table_1.csv
#   표 2 -> 수협중앙회_수협중앙회 수산물사이버직매장 시스템 재구축 ISMP 수립 입_table_2.csv
#   완료: 373개 단락, 2개 표
# 처리 중: 국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축.hwp
#   표 1 -> 국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축_table_1.csv
#   표 2 -> 국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축_table_2.csv
#   표 3 -> 국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축_table_3.csv
#   완료: 470개 단락, 3개 표
# 처리 중: 조선대학교_(재공고)2024 조선대학교 SW중심대학 사업관리시스템(WeHub) 구.hwp
#   표 1 -> 조선대학교_(재공고)2024 조선대학교 SW중심대학 사업관리시스템(WeHub) 구_table_1.csv
#   완료: 134개 단락, 1개 표
# 처리 중: 국민연금공단_2024년 이러닝시스템 운영 용역.hwp
#   표 1 -> 국민연금공단_2024년 이러닝시스템 운영 용역_table_1.csv
#   표 2 -> 국민연금공단_2024년 이러닝시스템 운영 용역_table_2.csv
#   완료: 312개 단락, 2개 표
# 처리 중: 한국보건산업진흥원_의료기기산업 종합정보시스템(정보관리기관) 기능.hwp
#   완료: 393개 단락, 0개 표
# 처리 중: 울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역.hwp
#   표 1 -> 울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역_table_1.csv
#   표 2 -> 울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역_table_2.csv
#   표 3 -> 울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역_table_3.csv
#   완료: 336개 단락, 3개 표
# 처리 중: BioIN_의료기기산업 종합정보시스템(정보관리기관) 기능개선 사업(2차).hwp
#   완료: 393개 단락, 0개 표
# 처리 중: 부산관광공사_경영정보시스템 기능개선.hwp
#   표 1 -> 부산관광공사_경영정보시스템 기능개선_table_1.csv
#   표 2 -> 부산관광공사_경영정보시스템 기능개선_table_2.csv
#   표 3 -> 부산관광공사_경영정보시스템 기능개선_table_3.csv
#   표 4 -> 부산관광공사_경영정보시스템 기능개선_table_4.csv
#   완료: 326개 단락, 4개 표
# 처리 중: 국가철도공단_철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역(변.hwp
#   표 1 -> 국가철도공단_철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역(변_table_1.csv
#   표 2 -> 국가철도공단_철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역(변_table_2.csv
#   완료: 339개 단락, 2개 표
# 처리 중: 고양도시관리공사_관산근린공원 다목적구장 홈페이지 및 회원 통합운영.hwp
#   완료: 274개 단락, 0개 표
# 처리 중: 한국재정정보원_e나라도움 업무시스템 웹 접근성 컨설팅.hwp
#   완료: 329개 단락, 0개 표
# 처리 중: 한국생산기술연구원_2세대 전자조달시스템  기반구축사업.hwp
#   표 1 -> 한국생산기술연구원_2세대 전자조달시스템  기반구축사업_table_1.csv
#   완료: 280개 단락, 1개 표
# 처리 중: 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp
#   표 1 -> 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역_table_1.csv
#   표 2 -> 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역_table_2.csv
#   표 3 -> 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역_table_3.csv
#   완료: 302개 단락, 3개 표
# 처리 중: 한국지식재산보호원_IP-NAVI  해외지식재산센터 사업관리 시스템 기능개.hwp
#   완료: 247개 단락, 0개 표
# 처리 중: 대한상공회의소_기업 재생에너지 지원센터 홈페이지 개편 및 시스템 고.hwp
#   완료: 307개 단락, 0개 표
# 처리 중: 인천광역시 동구_수도국산달동네박물관 전시해설 시스템 구축(협상에 .hwp
#   표 1 -> 인천광역시 동구_수도국산달동네박물관 전시해설 시스템 구축(협상에 _table_1.csv
#   완료: 274개 단락, 1개 표
# 처리 중: 대한장애인체육회_2025년 전국장애인체육대회 전산 및 시스템, 홈페이지 .hwp
#   표 1 -> 대한장애인체육회_2025년 전국장애인체육대회 전산 및 시스템, 홈페이지 _table_1.csv
#   완료: 257개 단락, 1개 표
# 처리 중: 인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp
#   표 1 -> 인천광역시_도시계획위원회 통합관리시스템 구축용역_table_1.csv
#   표 2 -> 인천광역시_도시계획위원회 통합관리시스템 구축용역_table_2.csv
#   완료: 240개 단락, 2개 표
# 처리 중: 경희대학교_[입찰공고] 산학협력단 정보시스템 운영 용역업체 선정.hwp
#   표 1 -> 경희대학교_[입찰공고] 산학협력단 정보시스템 운영 용역업체 선정_table_1.csv
#   표 2 -> 경희대학교_[입찰공고] 산학협력단 정보시스템 운영 용역업체 선정_table_2.csv
#   완료: 155개 단락, 2개 표
# 처리 중: 국방과학연구소_대용량 자료전송시스템 고도화.hwp
#   표 1 -> 국방과학연구소_대용량 자료전송시스템 고도화_table_1.csv
#   표 2 -> 국방과학연구소_대용량 자료전송시스템 고도화_table_2.csv
#   표 3 -> 국방과학연구소_대용량 자료전송시스템 고도화_table_3.csv
#   표 4 -> 국방과학연구소_대용량 자료전송시스템 고도화_table_4.csv
#   완료: 136개 단락, 4개 표
# 처리 중: 광주과학기술원_학사시스템 기능개선 사업.hwp
#   표 1 -> 광주과학기술원_학사시스템 기능개선 사업_table_1.csv
#   표 2 -> 광주과학기술원_학사시스템 기능개선 사업_table_2.csv
#   완료: 190개 단락, 2개 표
# 처리 중: 국가과학기술지식정보서비스_통합정보시스템 고도화 용역.hwp
#   표 1 -> 국가과학기술지식정보서비스_통합정보시스템 고도화 용역_table_1.csv
#   표 2 -> 국가과학기술지식정보서비스_통합정보시스템 고도화 용역_table_2.csv
#   완료: 284개 단락, 2개 표
# 처리 중: 사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.hwp
#   표 1 -> 사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업_table_1.csv
#   표 2 -> 사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업_table_2.csv
#   완료: 255개 단락, 2개 표
# 처리 중: 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 .hwp
#   표 1 -> 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 _table_1.csv
#   표 2 -> 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 _table_2.csv
#   표 3 -> 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 _table_3.csv
#   표 4 -> 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 _table_4.csv
#   표 5 -> 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 _table_5.csv
#   표 6 -> 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 _table_6.csv
#   표 7 -> 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 _table_7.csv
#   표 8 -> 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 _table_8.csv
#   완료: 213개 단락, 8개 표
# 처리 중: 축산물품질평가원_축산물이력관리시스템 개선(정보화 사업).hwp
#   완료: 213개 단락, 0개 표
# 처리 중: 문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자.hwp
#   표 1 -> 문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자_table_1.csv
#   표 2 -> 문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자_table_2.csv
#   표 3 -> 문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자_table_3.csv
#   표 4 -> 문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자_table_4.csv
#   완료: 270개 단락, 4개 표
# 처리 중: 한국로봇산업진흥원_한국로봇산업진흥원 사업관리시스템 온라인평가 .hwp
#   표 1 -> 한국로봇산업진흥원_한국로봇산업진흥원 사업관리시스템 온라인평가 _table_1.csv
#   표 2 -> 한국로봇산업진흥원_한국로봇산업진흥원 사업관리시스템 온라인평가 _table_2.csv
#   표 3 -> 한국로봇산업진흥원_한국로봇산업진흥원 사업관리시스템 온라인평가 _table_3.csv
#   완료: 218개 단락, 3개 표
# 처리 중: 축산물품질평가원_꿀 품질평가 전산시스템 기능개선 사업.hwp
#   완료: 228개 단락, 0개 표
# 처리 중: 중앙선거관리위원회_2025년도 행정정보시스템 위탁운영사업.hwp
#   완료: 273개 단락, 0개 표
# 처리 중: 서영대학교 산학협력단_전문대학 혁신지원사업 서영대학교 차세대 교육.hwp
#   표 1 -> 서영대학교 산학협력단_전문대학 혁신지원사업 서영대학교 차세대 교육_table_1.csv
#   완료: 300개 단락, 1개 표
# 처리 중: 남서울대학교_[혁신-국고] 남서울대학교 스마트 정보시스템 활성화(학사.hwp
#   표 1 -> 남서울대학교_[혁신-국고] 남서울대학교 스마트 정보시스템 활성화(학사_table_1.csv
#   완료: 217개 단락, 1개 표
# 처리 중: 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역.hwp
#   표 1 -> 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역_table_1.csv
#   표 2 -> 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역_table_2.csv
#   표 3 -> 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역_table_3.csv
#   표 4 -> 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역_table_4.csv
#   표 5 -> 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역_table_5.csv
#   완료: 277개 단락, 5개 표
# 처리 중: (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .hwp
#   완료: 573개 단락, 0개 표
# 처리 중: (사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원시.hwp
#   표 1 -> (사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원시_table_1.csv
#   완료: 181개 단락, 1개 표
# 처리 중: 한국보육진흥원_연차별 자율 품질관리 시스템 기능개선.hwp
#   완료: 268개 단락, 0개 표
# 처리 중: 재단법인 광주연구원_광주정책연구아카이브(GPA) 시스템 개발.hwp
#   완료: 303개 단락, 0개 표
# 처리 중: 대한적십자사 의료원_적십자병원 병원정보 재해복구시스템 구축 용역 .hwp
#   표 1 -> 대한적십자사 의료원_적십자병원 병원정보 재해복구시스템 구축 용역 _table_1.csv
#   완료: 153개 단락, 1개 표
# 처리 중: 한국농어촌공사_네팔 수자원관리 정보화사업-Pilot 시스템 구축용역.hwp
#   표 1 -> 한국농어촌공사_네팔 수자원관리 정보화사업-Pilot 시스템 구축용역_table_1.csv
#   완료: 272개 단락, 1개 표
# 처리 중: 한국발명진흥회 입찰공고_2024년 건설기술에 관한 특허·실용신안 활용실.hwp
#   완료: 311개 단락, 0개 표
# 처리 중: 경기도사회서비스원_2024년 통합사회정보시스템 운영지원.hwp
#   완료: 226개 단락, 0개 표
# 처리 중: 인천광역시_인천일자리플랫폼 정보시스템 구축 ISP 수립용역.hwp
#   표 1 -> 인천광역시_인천일자리플랫폼 정보시스템 구축 ISP 수립용역_table_1.csv
#   완료: 239개 단락, 1개 표
# 처리 중: 국방과학연구소_기록관리시스템 통합 활용 및 보안 환경 구축.hwp
#   완료: 277개 단락, 0개 표
# 처리 중: 한국해양조사협회_2024년 항해용 간행물 품질관리 업무보조 시스템 구축.hwp
#   표 1 -> 한국해양조사협회_2024년 항해용 간행물 품질관리 업무보조 시스템 구축_table_1.csv
#   완료: 582개 단락, 1개 표
# 처리 중: 한국농어촌공사_아세안+3 식량안보정보시스템(AFSIS) 3단계 협력(캄보디아.hwp
# [실패] ../data/raw/files/한국농어촌공사_아세안+3 식량안보정보시스템(AFSIS) 3단계 협력(캄보디아.hwp : Traceback (most recent call last):
#   File "/home/spai0323/myenv/bin/hwp5txt", line 33, in <module>
#     sys.exit(load_entry_point('pyhwp==0.1b15', 'console_scripts', 'hwp5txt')())
#   File "/home/spai0323/myenv/lib/python3.10/site-packages/hwp5/hwp5txt.py", line 84, in main
#     transform(hwp5file, dest)
#   File "/home/spai0323/myenv/lib/python3.10/site-packages/hwp5/transforms/__init__.py", line 50, in transform_hwp5
#     return transform_xhwp5(xhwp5path, output)
#   File "/home/spai0323/myenv/lib/python3.10/site-packages/hwp5/plat/_lxml.py", line 95, in transform_into_stream
#     return self._transform(inp_file, output)
#   File "/home/spai0323/myenv/lib/python3.10/site-packages/hwp5/plat/_lxml.py", line 101, in _transform
#     source = etree.parse(input)
#   File "src/lxml/etree.pyx", line 3711, in lxml.etree.parse
#   File "src/lxml/parser.pxi", line 2045, in lxml.etree._parseDocument
#   File "src/lxml/parser.pxi", line 2063, in lxml.etree._parseFilelikeDocument
#   File "src/lxml/parser.pxi", line 1958, in lxml.etree._parseDocFromFilelike
#   File "src/lxml/parser.pxi", line 1251, in lxml.etree._BaseParser._parseDocFromFilelike
#   File "src/lxml/parser.pxi", line 647, in lxml.etree._ParserContext._handleParseResultDoc
#   File "src/lxml/parser.pxi", line 765, in lxml.etree._handleParseResult
#   File "src/lxml/parser.pxi", line 689, in lxml.etree._raiseParseError
#   File "/tmp/tmpry862onn", line 2
# lxml.etree.XMLSyntaxError: invalid character in attribute value, line 2, column 2063420
#
# 처리 중: 국립인천해양박물관_국립인천해양박물관 해양자료관리시스템 구축 용.hwp
#   표 1 -> 국립인천해양박물관_국립인천해양박물관 해양자료관리시스템 구축 용_table_1.csv
#   표 2 -> 국립인천해양박물관_국립인천해양박물관 해양자료관리시스템 구축 용_table_2.csv
#   완료: 365개 단락, 2개 표
# 처리 중: 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센.hwp
#   표 1 -> 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센_table_1.csv
#   표 2 -> 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센_table_2.csv
#   표 3 -> 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센_table_3.csv
#   표 4 -> 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센_table_4.csv
#   표 5 -> 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센_table_5.csv
#   표 6 -> 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센_table_6.csv
#   표 7 -> 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센_table_7.csv
#   완료: 351개 단락, 7개 표
# 처리 중: 국민연금공단_사업장 사회보험료 지원 고시 개정에 따른 정보시스템 보.hwp
#   완료: 236개 단락, 0개 표
# 처리 중: 한국수자원공사_용인 첨단 시스템반도체 국가산단 용수공급사업 타당성.hwp
#   완료: 55개 단락, 0개 표
# 처리 중: 재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스.hwp
#   표 1 -> 재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스_table_1.csv
#   표 2 -> 재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스_table_2.csv
#   표 3 -> 재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스_table_3.csv
#   표 4 -> 재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스_table_4.csv
#   완료: 260개 단락, 4개 표
# 처리 중: 수협중앙회_강릉어선안전조업국 상황관제시스템 구축.hwp
#   표 1 -> 수협중앙회_강릉어선안전조업국 상황관제시스템 구축_table_1.csv
#   완료: 237개 단락, 1개 표
# 처리 중: 한국철도공사 (용역)_예약발매시스템 개량 ISMP 용역.hwp
#   표 1 -> 한국철도공사 (용역)_예약발매시스템 개량 ISMP 용역_table_1.csv
#   완료: 490개 단락, 1개 표
# 처리 중: 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp
#   표 1 -> 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선_table_1.csv
#   표 2 -> 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선_table_2.csv
#   완료: 248개 단락, 2개 표
# 처리 중: 한국어촌어항공단_한국어촌어항공단 경영관리시스템(ERP·GW) 기능 고도.hwp
#   완료: 316개 단락, 0개 표
# 처리 중: 을지대학교_을지대학교 비교과시스템 개발.hwp
#   표 1 -> 을지대학교_을지대학교 비교과시스템 개발_table_1.csv
#   완료: 198개 단락, 1개 표
# 처리 중: 2025 구미 아시아육상경기선수권대회 조직위원회_2025 구미아시아육상경.hwp
#   완료: 193개 단락, 0개 표
# 처리 중: 재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음.hwp
#   표 1 -> 재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음_table_1.csv
#   표 2 -> 재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음_table_2.csv
#   표 3 -> 재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음_table_3.csv
#   표 4 -> 재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음_table_4.csv
#   표 5 -> 재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음_table_5.csv
#   완료: 199개 단락, 5개 표
# 처리 중: 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급).hwp
#   표 1 -> 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)_table_1.csv
#   표 2 -> 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)_table_2.csv
#   표 3 -> 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)_table_3.csv
#   표 4 -> 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)_table_4.csv
#   표 5 -> 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)_table_5.csv
#   표 6 -> 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)_table_6.csv
#   완료: 245개 단락, 6개 표
# 처리 중: 서민금융진흥원_서민금융진흥원 서민금융 채팅 상담시스템 구축.hwp
#   완료: 296개 단락, 0개 표
# 처리 중: 한국산업단지공단_산단 안전정보시스템 1차 구축 용역.hwp
#   완료: 379개 단락, 0개 표
# 처리 중: 대검찰청_아태 사이버범죄 역량강화 허브(APC-HUB) 홈페이지 및 온라인 교.hwp
#   표 1 -> 대검찰청_아태 사이버범죄 역량강화 허브(APC-HUB) 홈페이지 및 온라인 교_table_1.csv
#   완료: 178개 단락, 1개 표
# 처리 중: 광주과학기술원_실시간통합연구비관리시스템(RCMS)  연계 모듈 변경 사업.hwp
#   표 1 -> 광주과학기술원_실시간통합연구비관리시스템(RCMS)  연계 모듈 변경 사업_table_1.csv
#   표 2 -> 광주과학기술원_실시간통합연구비관리시스템(RCMS)  연계 모듈 변경 사업_table_2.csv
#   완료: 263개 단락, 2개 표
# 처리 중: 전북대학교_JST 공유대학(원) xAPI기반 LRS시스템 구축.hwp
#   표 1 -> 전북대학교_JST 공유대학(원) xAPI기반 LRS시스템 구축_table_1.csv
#   표 2 -> 전북대학교_JST 공유대학(원) xAPI기반 LRS시스템 구축_table_2.csv
#   표 3 -> 전북대학교_JST 공유대학(원) xAPI기반 LRS시스템 구축_table_3.csv
#   완료: 202개 단락, 3개 표
# 처리 중: 경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업.hwp
#   표 1 -> 경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업_table_1.csv
#   표 2 -> 경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업_table_2.csv
#   표 3 -> 경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업_table_3.csv
#   표 4 -> 경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업_table_4.csv
#   완료: 283개 단락, 4개 표
# 처리 중: 한국철도공사 (용역)_[재공고][긴급][협상형]운행정보기록 자동분석시스.hwp
#   표 1 -> 한국철도공사 (용역)_[재공고][긴급][협상형]운행정보기록 자동분석시스_table_1.csv
#   표 2 -> 한국철도공사 (용역)_[재공고][긴급][협상형]운행정보기록 자동분석시스_table_2.csv
#   완료: 440개 단락, 2개 표
# 처리 중: 재단법인경기도일자리재단_2025년 통합접수시스템 운영.hwp
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 283
#     280     print("pandas를 설치해주세요: pip install pandas")
#     281     exit(1)
# --> 283 hwp_folder_to_json_improved(raw_folder, processed_folder)
#     284 print("모든 HWP 파일이 처리되었습니다.")
#     285 print("- JSON: data/processed/json_output/")
#
# Cell In[9], line 220, in hwp_folder_to_json_improved(raw_folder, processed_folder)
#     217 print(f"처리 중: {hwp_file}")
#     219 # 텍스트 추출
# --> 220 result = extract_hwp_structured(hwp_path)
#     221 if result[0] is None:
#     222     summary["failed_files"] += 1
#
# Cell In[9], line 43, in extract_hwp_structured(hwp_path)
#      40     pass
#      42 # 일반 텍스트 추출
# ---> 43 text = extract_hwp_text_advanced(hwp_path)
#      44 return text, "text" if text else None
#
# Cell In[9], line 15, in extract_hwp_text_advanced(hwp_path)
#      12 """hwp5txt로 HWP 텍스트 추출 - 다양한 옵션 시도"""
#      13 try:
#      14     # 기본 추출 시도
# ---> 15     result = subprocess.run(
#      16         [HWP5TXT_PATH, hwp_path],
#      17         stdout=subprocess.PIPE,
#      18         stderr=subprocess.PIPE,
#      19         text=True,
#      20         check=True
#      21     )
#      22     return result.stdout
#      23 except subprocess.CalledProcessError as e:
#
# File /usr/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File /usr/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:2021, in Popen._communicate(self, input, endtime, orig_timeout)
#    2014     self._check_timeout(endtime, orig_timeout,
#    2015                         stdout, stderr,
#    2016                         skip_check_and_raise=True)
#    2017     raise RuntimeError(  # Impossible :)
#    2018         '_check_timeout(..., skip_check_and_raise=True) '
#    2019         'failed to raise TimeoutExpired.')
# -> 2021 ready = selector.select(timeout)
#    2022 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2024 # XXX Rewrite these to use non-blocking I/O on the file
#    2025 # objects; they are no longer using C stdio!
#
# File /usr/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
import shutil

# 삭제할 폴더 경로를 지정하세요.
folder_path = '/home/spai0323/projectmission2/data/processed/json_output'

try:
    shutil.rmtree(folder_path)
    print(f"'{folder_path}' 폴더와 모든 내용이 성공적으로 삭제되었습니다.")
except OSError as e:
    print(f"오류: {e.strerror} - {e.filename}")
# Out:
# '/home/spai0323/projectmission2/data/processed/json_output' 폴더와 모든 내용이 성공적으로 삭제되었습니다.
