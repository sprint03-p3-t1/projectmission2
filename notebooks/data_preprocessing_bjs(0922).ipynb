# %%
# %pip install chromadb
# Out:
# Requirement already satisfied: chromadb in /opt/jhub-venv/lib/python3.10/site-packages (1.0.21)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: importlib-resources in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: pydantic>=1.9 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (2.11.7)
# Requirement already satisfied: numpy>=1.22.5 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (2.1.2)
# Requirement already satisfied: build>=1.0.3 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: httpx>=0.27.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: pyyaml>=6.0.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: pybase64>=1.4.1 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (1.22.1)
# Requirement already satisfied: typer>=0.9.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (0.17.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: overrides>=7.3.1 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: rich>=10.11.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (0.35.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (0.22.0)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: pypika>=0.48.9 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (1.74.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/jhub-venv/lib/python3.10/site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/jhub-venv/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: pyproject_hooks in /opt/jhub-venv/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: packaging>=19.1 in /opt/jhub-venv/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: idna in /opt/jhub-venv/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: anyio in /opt/jhub-venv/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /opt/jhub-venv/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: certifi in /opt/jhub-venv/lib/python3.10/site-packages (from httpx>=0.27.0->chromadb) (2025.8.3)
# Requirement already satisfied: h11>=0.16 in /opt/jhub-venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/jhub-venv/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/jhub-venv/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: referencing>=0.28.4 in /opt/jhub-venv/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/jhub-venv/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: requests in /opt/jhub-venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Requirement already satisfied: durationpy>=0.7 in /opt/jhub-venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: urllib3>=1.24.2 in /opt/jhub-venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: requests-oauthlib in /opt/jhub-venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/jhub-venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/jhub-venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: six>=1.9.0 in /opt/jhub-venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/jhub-venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/jhub-venv/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: coloredlogs in /opt/jhub-venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/jhub-venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /opt/jhub-venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in /opt/jhub-venv/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/jhub-venv/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /opt/jhub-venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/jhub-venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /opt/jhub-venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/jhub-venv/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.58b0)
# Requirement already satisfied: backoff>=1.10.0 in /opt/jhub-venv/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /opt/jhub-venv/lib/python3.10/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/jhub-venv/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/jhub-venv/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/jhub-venv/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/jhub-venv/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/jhub-venv/lib/python3.10/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/jhub-venv/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb) (0.34.4)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/jhub-venv/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /opt/jhub-venv/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/jhub-venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /opt/jhub-venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/jhub-venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: httptools>=0.6.3 in /opt/jhub-venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in /opt/jhub-venv/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/jhub-venv/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/jhub-venv/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/jhub-venv/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/jhub-venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.10)
# Requirement already satisfied: filelock in /opt/jhub-venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/jhub-venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=3.20 in /opt/jhub-venv/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/jhub-venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/jhub-venv/lib/python3.10/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/jhub-venv/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/jhub-venv/lib/python3.10/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/jhub-venv/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/jhub-venv/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/jhub-venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pyhwp
# Out:
# Requirement already satisfied: pyhwp in /home/spai0323/myenv/lib/python3.10/site-packages (0.1b15)
# Requirement already satisfied: cryptography in /opt/jhub-venv/lib/python3.10/site-packages (from pyhwp) (45.0.7)
# Requirement already satisfied: lxml in /opt/jhub-venv/lib/python3.10/site-packages (from pyhwp) (6.0.1)
# Requirement already satisfied: olefile>=0.43 in /opt/jhub-venv/lib/python3.10/site-packages (from pyhwp) (0.47)
# Requirement already satisfied: cffi>=1.14 in /opt/jhub-venv/lib/python3.10/site-packages (from cryptography->pyhwp) (2.0.0)
# Requirement already satisfied: pycparser in /opt/jhub-venv/lib/python3.10/site-packages (from cffi>=1.14->cryptography->pyhwp) (2.23)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in /opt/jhub-venv/lib/python3.10/site-packages (0.3.29)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: requests<3,>=2.32.5 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (0.3.76)
# Requirement already satisfied: langsmith>=0.1.125 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (0.4.27)
# Requirement already satisfied: PyYAML>=5.3 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: numpy>=1.26.2 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (2.1.2)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/jhub-venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/jhub-venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/jhub-venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/jhub-venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/jhub-venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/jhub-venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/jhub-venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/jhub-venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/jhub-venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/jhub-venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (2.11.7)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (0.3.11)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (25.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/jhub-venv/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/jhub-venv/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: orjson>=3.9.14 in /opt/jhub-venv/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain-community) (3.11.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/jhub-venv/lib/python3.10/site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/jhub-venv/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/jhub-venv/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/jhub-venv/lib/python3.10/site-packages (from requests<3,>=2.32.5->langchain-community) (2025.8.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/jhub-venv/lib/python3.10/site-packages (from requests<3,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/jhub-venv/lib/python3.10/site-packages (from requests<3,>=2.32.5->langchain-community) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/jhub-venv/lib/python3.10/site-packages (from requests<3,>=2.32.5->langchain-community) (3.10)
# Requirement already satisfied: greenlet>=1 in /opt/jhub-venv/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.4)
# Requirement already satisfied: anyio in /opt/jhub-venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /opt/jhub-venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/jhub-venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/jhub-venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain-community) (3.0.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/jhub-venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/jhub-venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/jhub-venv/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/jhub-venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/jhub-venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in /home/spai0323/myenv/lib/python3.10/site-packages (0.3.33)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.76 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-openai) (0.3.76)
# Requirement already satisfied: openai<2.0.0,>=1.104.2 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-openai) (1.107.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/spai0323/myenv/lib/python3.10/site-packages (from langchain-openai) (0.11.0)
# Requirement already satisfied: PyYAML>=5.3 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.76->langchain-openai) (6.0.2)
# Requirement already satisfied: pydantic>=2.7.4 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.76->langchain-openai) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.76->langchain-openai) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.76->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.76->langchain-openai) (4.12.2)
# Requirement already satisfied: langsmith>=0.3.45 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.76->langchain-openai) (0.4.27)
# Requirement already satisfied: packaging>=23.2 in /opt/jhub-venv/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.76->langchain-openai) (25.0)
# Requirement already satisfied: tqdm>4 in /opt/jhub-venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/jhub-venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /opt/jhub-venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/jhub-venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/jhub-venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.10.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/jhub-venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (0.28.1)
# Requirement already satisfied: regex>=2022.1.18 in /opt/jhub-venv/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2025.9.1)
# Requirement already satisfied: requests>=2.26.0 in /opt/jhub-venv/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.5)
# Requirement already satisfied: idna>=2.8 in /opt/jhub-venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.104.2->langchain-openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/jhub-venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.104.2->langchain-openai) (1.3.0)
# Requirement already satisfied: certifi in /opt/jhub-venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.104.2->langchain-openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/jhub-venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.104.2->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/jhub-venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.104.2->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/jhub-venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.76->langchain-openai) (3.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/jhub-venv/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.76->langchain-openai) (0.25.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/jhub-venv/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.76->langchain-openai) (1.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /opt/jhub-venv/lib/python3.10/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.76->langchain-openai) (3.11.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/jhub-venv/lib/python3.10/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.76->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/jhub-venv/lib/python3.10/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.76->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/jhub-venv/lib/python3.10/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.76->langchain-openai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/jhub-venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/jhub-venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U langchain-chroma

# %%
import os
import subprocess
from bs4 import BeautifulSoup
import re
from typing import List, Dict, Any
import json
import tiktoken

########################################
# 1. HWP → XHTML 변환 함수
########################################
def convert_all_hwps_in_folder(input_directory, output_directory, hwp5proc_executable="/home/spai0323/myenv/bin/hwp5proc"):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    converted_files = []
    for filename in os.listdir(input_directory):
        if filename.lower().endswith(".hwp"):
            input_path = os.path.join(input_directory, filename)
            base_name, _ = os.path.splitext(filename)
            output_path = os.path.join(output_directory, f'{base_name}.xhtml')

            command = [hwp5proc_executable, "xml", input_path]

            try:
                result = subprocess.run(command, capture_output=True, text=True, check=True)
                with open(output_path, 'w', encoding='utf-8') as f:
                    f.write(result.stdout)
                print(f"✅ 변환 성공: {filename}")
                converted_files.append(output_path)
            except Exception as e:
                print(f"❌ 변환 실패 {filename}: {e}")
    return converted_files

########################################
# 2. XHTML 파싱 함수
########################################
def parse_hwp5proc_xhtml(file_path):
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
        content = f.read()
    soup = BeautifulSoup(content, 'xml')

    parsed_data = {'sections': [], 'tables': [], 'metadata': {}}

    # 표 추출
    tables = soup.find_all('TableControl')
    for i, table in enumerate(tables):
        table_data = extract_table_structure(table, table_id=i)
        if table_data:
            parsed_data['tables'].append(table_data)

    # 문단 추출
    paragraphs = soup.find_all('Paragraph')
    for i, para in enumerate(paragraphs):
        text_content = extract_paragraph_text(para, para_id=i)
        if text_content and text_content.get('content', '').strip():
            parsed_data['sections'].append(text_content)

    parsed_data['metadata'] = {
        'total_paragraphs': len(parsed_data['sections']),
        'total_tables': len(parsed_data['tables']),
        'file_size': len(content)
    }
    return parsed_data

def extract_table_structure(table_element, table_id):
    table_data = {'id': table_id, 'rows': [], 'raw_content': ''}
    table_body = table_element.find('TableBody')
    if not table_body:
        return None
    for row in table_body.find_all('TableRow'):
        row_data = []
        for cell in row.find_all('TableCell'):
            text = " ".join([t.string.strip() for t in cell.find_all('Text') if t.string])
            row_data.append(text)
        if any(row_data):
            table_data['rows'].append(row_data)
    table_data['raw_content'] = convert_table_to_natural_language(table_data['rows'])
    return table_data

def extract_paragraph_text(paragraph_element, para_id):
    text_content = " ".join([t.string.strip() for t in paragraph_element.find_all('Text') if t.string])
    return {'id': para_id, 'type': 'paragraph', 'content': text_content}

def convert_table_to_natural_language(table_rows):
    if not table_rows or len(table_rows) < 2:
        return ""
    headers, *rows = table_rows
    natural_texts = []
    for row in rows:
        row_text = [f"{h}: {c}" for h, c in zip(headers, row) if c.strip()]
        if row_text:
            natural_texts.append(", ".join(row_text))
    return ". ".join(natural_texts)

########################################
# 3. 청킹 함수
########################################
def create_structured_chunks(parsed_data: Dict[str, Any], max_chunk_size: int = 100) -> List[Dict[str, Any]]:
    chunks = []
    for table in parsed_data['tables']:
        if table['raw_content']:
            chunks.append({'type': 'table', 'content': table['raw_content']})
    for section in parsed_data['sections']:
        content = section['content']
        if len(content) <= max_chunk_size:
            chunks.append({'type': 'paragraph', 'content': content})
        else:
            chunks.extend(split_large_paragraph_by_tokens(content, max_chunk_size))
    for i, chunk in enumerate(chunks):
        chunk['chunk_id'] = f"chunk_{i:04d}"
    return chunks

def split_large_paragraph_by_tokens(content: str, max_chunk_size: int):
    encoding = tiktoken.get_encoding("cl100k_base") # embedding-3-small 모델에 사용되는 인코딩
    sentences = re.split(r'[.!?]\s+', content)
    chunks, current_tokens, current_chunk = [], 0, []

    for s in sentences:
        sentence_tokens = len(encoding.encode(s))
        if current_tokens + sentence_tokens <= max_chunk_size:
            current_chunk.append(s)
            current_tokens += sentence_tokens
        else:
            chunks.append({'type': 'paragraph', 'content': ". ".join(current_chunk)})
            current_chunk, current_tokens = [s], sentence_tokens

    if current_chunk:
        chunks.append({'type': 'paragraph', 'content': ". ".join(current_chunk)})
    return chunks

########################################
# 4. json 파일 생성 및 저장
########################################
import json
import os

def save_chunks_to_json(chunks, source_file, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    base_name = os.path.splitext(os.path.basename(source_file))[0]
    output_path = os.path.join(output_dir, f"{base_name}.json")

    # 청크에 메타데이터 추가
    for chunk in chunks:
        chunk["source_file"] = base_name

    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(chunks, f, ensure_ascii=False, indent=2)

    print(f"💾 저장 완료: {output_path}")

########################################
# 5. 전체 실행 메인
########################################
def main_pipeline():
    input_folder = "../data/raw/files"
    output_folder = "../data/processed/bydatapreprocessingbjs(0922)/all_xhtml"
    os.makedirs(output_folder, exist_ok=True)
    json_output_dir = "../data/processed/bydatapreprocessingbjs(0922)/json"
    
    # 1. 변환
    converted_files = convert_all_hwps_in_folder(input_folder, output_folder)

    # 2. 파싱 + 3. 청킹
    for file_path in converted_files:
        print(f"\n=== 처리 중: {file_path} ===")
        parsed_data = parse_hwp5proc_xhtml(file_path)
        chunks = create_structured_chunks(parsed_data)
        print(f"문단 {len(parsed_data['sections'])}, 표 {len(parsed_data['tables'])}, 청크 {len(chunks)}개 생성")

        save_chunks_to_json(chunks, file_path, json_output_dir)

if __name__ == "__main__":
    main_pipeline()
# Out:
# ✅ 변환 성공: 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구.hwp
# ✅ 변환 성공: 케빈랩 주식회사_평택시 강소형 스마트시티 AI 기반의 영상감시 시스템 .hwp
# ✅ 변환 성공: 수협중앙회_수협중앙회 수산물사이버직매장 시스템 재구축 ISMP 수립 입.hwp
# ✅ 변환 성공: 국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축.hwp
# ✅ 변환 성공: 조선대학교_(재공고)2024 조선대학교 SW중심대학 사업관리시스템(WeHub) 구.hwp
# ✅ 변환 성공: 국민연금공단_2024년 이러닝시스템 운영 용역.hwp
# ✅ 변환 성공: 한국보건산업진흥원_의료기기산업 종합정보시스템(정보관리기관) 기능.hwp
# ✅ 변환 성공: 울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역.hwp
# ✅ 변환 성공: BioIN_의료기기산업 종합정보시스템(정보관리기관) 기능개선 사업(2차).hwp
# ✅ 변환 성공: 부산관광공사_경영정보시스템 기능개선.hwp
# ✅ 변환 성공: 국가철도공단_철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역(변.hwp
# ✅ 변환 성공: 고양도시관리공사_관산근린공원 다목적구장 홈페이지 및 회원 통합운영.hwp
# ✅ 변환 성공: 한국재정정보원_e나라도움 업무시스템 웹 접근성 컨설팅.hwp
# ✅ 변환 성공: 한국생산기술연구원_2세대 전자조달시스템  기반구축사업.hwp
# ✅ 변환 성공: 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp
# ✅ 변환 성공: 한국지식재산보호원_IP-NAVI  해외지식재산센터 사업관리 시스템 기능개.hwp
# ✅ 변환 성공: 대한상공회의소_기업 재생에너지 지원센터 홈페이지 개편 및 시스템 고.hwp
# ✅ 변환 성공: 인천광역시 동구_수도국산달동네박물관 전시해설 시스템 구축(협상에 .hwp
# ✅ 변환 성공: 대한장애인체육회_2025년 전국장애인체육대회 전산 및 시스템, 홈페이지 .hwp
# ✅ 변환 성공: 인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp
# ✅ 변환 성공: 경희대학교_[입찰공고] 산학협력단 정보시스템 운영 용역업체 선정.hwp
# ✅ 변환 성공: 국방과학연구소_대용량 자료전송시스템 고도화.hwp
# ✅ 변환 성공: 광주과학기술원_학사시스템 기능개선 사업.hwp
# ✅ 변환 성공: 국가과학기술지식정보서비스_통합정보시스템 고도화 용역.hwp
# ✅ 변환 성공: 사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.hwp
# ✅ 변환 성공: 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 .hwp
# ✅ 변환 성공: 축산물품질평가원_축산물이력관리시스템 개선(정보화 사업).hwp
# ✅ 변환 성공: 문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자.hwp
# ✅ 변환 성공: 한국로봇산업진흥원_한국로봇산업진흥원 사업관리시스템 온라인평가 .hwp
# ✅ 변환 성공: 축산물품질평가원_꿀 품질평가 전산시스템 기능개선 사업.hwp
# ✅ 변환 성공: 중앙선거관리위원회_2025년도 행정정보시스템 위탁운영사업.hwp
# ✅ 변환 성공: 서영대학교 산학협력단_전문대학 혁신지원사업 서영대학교 차세대 교육.hwp
# ✅ 변환 성공: 남서울대학교_[혁신-국고] 남서울대학교 스마트 정보시스템 활성화(학사.hwp
# ✅ 변환 성공: 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역.hwp
# ✅ 변환 성공: (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .hwp
# ✅ 변환 성공: (사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원시.hwp
# ✅ 변환 성공: 한국보육진흥원_연차별 자율 품질관리 시스템 기능개선.hwp
# ✅ 변환 성공: 재단법인 광주연구원_광주정책연구아카이브(GPA) 시스템 개발.hwp
# ✅ 변환 성공: 대한적십자사 의료원_적십자병원 병원정보 재해복구시스템 구축 용역 .hwp
# ✅ 변환 성공: 한국농어촌공사_네팔 수자원관리 정보화사업-Pilot 시스템 구축용역.hwp
# ✅ 변환 성공: 한국발명진흥회 입찰공고_2024년 건설기술에 관한 특허·실용신안 활용실.hwp
# ✅ 변환 성공: 경기도사회서비스원_2024년 통합사회정보시스템 운영지원.hwp
# ✅ 변환 성공: 인천광역시_인천일자리플랫폼 정보시스템 구축 ISP 수립용역.hwp
# ✅ 변환 성공: 국방과학연구소_기록관리시스템 통합 활용 및 보안 환경 구축.hwp
# ✅ 변환 성공: 한국해양조사협회_2024년 항해용 간행물 품질관리 업무보조 시스템 구축.hwp
# ✅ 변환 성공: 한국농어촌공사_아세안+3 식량안보정보시스템(AFSIS) 3단계 협력(캄보디아.hwp
# ✅ 변환 성공: 국립인천해양박물관_국립인천해양박물관 해양자료관리시스템 구축 용.hwp
# ✅ 변환 성공: 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센.hwp
# ✅ 변환 성공: 국민연금공단_사업장 사회보험료 지원 고시 개정에 따른 정보시스템 보.hwp
# ✅ 변환 성공: 한국수자원공사_용인 첨단 시스템반도체 국가산단 용수공급사업 타당성.hwp
# ✅ 변환 성공: 재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스.hwp
# ✅ 변환 성공: 수협중앙회_강릉어선안전조업국 상황관제시스템 구축.hwp
# ✅ 변환 성공: 한국철도공사 (용역)_예약발매시스템 개량 ISMP 용역.hwp
# ✅ 변환 성공: 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp
# ✅ 변환 성공: 한국어촌어항공단_한국어촌어항공단 경영관리시스템(ERP·GW) 기능 고도.hwp
# ✅ 변환 성공: 을지대학교_을지대학교 비교과시스템 개발.hwp
# ✅ 변환 성공: 2025 구미 아시아육상경기선수권대회 조직위원회_2025 구미아시아육상경.hwp
# ✅ 변환 성공: 재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음.hwp
# ✅ 변환 성공: 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급).hwp
# ✅ 변환 성공: 서민금융진흥원_서민금융진흥원 서민금융 채팅 상담시스템 구축.hwp
# ✅ 변환 성공: 한국산업단지공단_산단 안전정보시스템 1차 구축 용역.hwp
# ✅ 변환 성공: 대검찰청_아태 사이버범죄 역량강화 허브(APC-HUB) 홈페이지 및 온라인 교.hwp
# ✅ 변환 성공: 광주과학기술원_실시간통합연구비관리시스템(RCMS)  연계 모듈 변경 사업.hwp
# ✅ 변환 성공: 전북대학교_JST 공유대학(원) xAPI기반 LRS시스템 구축.hwp
# ✅ 변환 성공: 경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업.hwp
# ✅ 변환 성공: 한국철도공사 (용역)_[재공고][긴급][협상형]운행정보기록 자동분석시스.hwp
# ✅ 변환 성공: 재단법인경기도일자리재단_2025년 통합접수시스템 운영.hwp
# ✅ 변환 성공: 한국농수산식품유통공사_농산물가격안정기금 정부예산회계연계시스템 .hwp
# ✅ 변환 성공: 서울특별시교육청_서울특별시교육청 지능정보화전략계획(ISP) 수립(2차) .hwp
# ✅ 변환 성공: 나노종합기술원_스마트 팹 서비스 활용체계 구축관련 설비온라인 시스.hwp
# ✅ 변환 성공: 한국철도공사 (용역)_모바일오피스 시스템 고도화 용역(총체 및 1차).hwp
# ✅ 변환 성공: 사단법인아시아물위원회사무국_우즈벡-키르기즈스탄 기후변화대응 스.hwp
# ✅ 변환 성공: 파주도시관광공사_종량제봉투 판매관리 전산시스템 개선사업.hwp
# ✅ 변환 성공: (재)예술경영지원센터_통합 정보시스템 구축 사전 컨설팅.hwp
# ✅ 변환 성공: 세종테크노파크_세종테크노파크 인사정보 전산시스템 구축 용역 입찰공.hwp
# ✅ 변환 성공: 한국가스공사_[재공고]차세대 통합정보시스템(ERP) 구축.hwp
# ✅ 변환 성공: 한국건강가정진흥원_2025년 아이돌봄인력 인적성 검사 정보시스템 운영.hwp
# ✅ 변환 성공: (사）한국대학스포츠협의회_KUSF 체육특기자 경기기록 관리시스템 개발.hwp
# ✅ 변환 성공: 한국산업인력공단_RFID기반 국가자격 시험 결과물 스마트 관리시스템 도.hwp
# ✅ 변환 성공: 한국수자원공사_수도사업장 통합 사고분석솔루션 시범구축 용역.hwp
# ✅ 변환 성공: 한국사회보장정보원_라오스 보건의료정보화 협력을 위한 사전타당성 조.hwp
# ✅ 변환 성공: 그랜드코리아레저(주)_2024년도 GKL  그룹웨어 시스템 구축 용역.hwp
# ✅ 변환 성공: 한국전기안전공사_전기안전 관제시스템 보안 모듈 개발 용역.hwp
# ✅ 변환 성공: 한국수자원공사_건설통합시스템(CMS) 고도화.hwp
# ✅ 변환 성공: 한국교육과정평가원_국가교육과정정보센터(NCIC) 시스템 운영 및 개선.hwp
# ✅ 변환 성공: 한국원자력연구원_한국원자력연구원 선량평가시스템 고도화.hwp
# ✅ 변환 성공: 재단법인충북연구원_GIS통계 기반 재난안전데이터 분석ㆍ관리 시스템 구.hwp
# ✅ 변환 성공: 한국수자원조사기술원_수문자료정보관리시스템(HDIMS) 재구축 용역(3단계.hwp
# ✅ 변환 성공: 한국한의학연구원_통합정보시스템 고도화 용역.hwp
# ✅ 변환 성공: 한국수출입은행_(긴급) 모잠비크 마푸토 지능형교통시스템(ITS) 구축사업.hwp
# ✅ 변환 성공: 한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp
# ✅ 변환 성공: 재단법인스포츠윤리센터_스포츠윤리센터 LMS(학습지원시스템) 기능개선.hwp
# ✅ 변환 성공: KOICA 전자조달_[긴급] [지문] [국제] 우즈베키스탄 열린 의정활동 상하원 .hwp
# ✅ 변환 성공: 한국사학진흥재단_대학재정정보시스템(기본재산 및 기채 사후관리) 고.hwp
# ✅ 변환 성공: 전북특별자치도 정읍시_정읍체육트레이닝센터 통합운영관리시스템 구.hwp
# ❌ 변환 실패 대전대학교_대전대학교 2024학년도 다층적 융합 학습경험 플랫폼(MILE) 전.hwp: Command '['/home/spai0323/myenv/bin/hwp5proc', 'xml', '../data/raw/files/대전대학교_대전대학교 2024학년도 다층적 융합 학습경험 플랫폼(MILE) 전.hwp']' returned non-zero exit status 1.
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구.xhtml ===
# 문단 2560, 표 100, 청크 2890개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/케빈랩 주식회사_평택시 강소형 스마트시티 AI 기반의 영상감시 시스템 .xhtml ===
# 문단 2534, 표 137, 청크 2796개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/케빈랩 주식회사_평택시 강소형 스마트시티 AI 기반의 영상감시 시스템 .json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/수협중앙회_수협중앙회 수산물사이버직매장 시스템 재구축 ISMP 수립 입.xhtml ===
# 문단 2565, 표 94, 청크 2872개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/수협중앙회_수협중앙회 수산물사이버직매장 시스템 재구축 ISMP 수립 입.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축.xhtml ===
# 문단 4656, 표 246, 청크 5251개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/조선대학교_(재공고)2024 조선대학교 SW중심대학 사업관리시스템(WeHub) 구.xhtml ===
# 문단 1869, 표 91, 청크 2207개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/조선대학교_(재공고)2024 조선대학교 SW중심대학 사업관리시스템(WeHub) 구.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/국민연금공단_2024년 이러닝시스템 운영 용역.xhtml ===
# 문단 2736, 표 73, 청크 3044개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/국민연금공단_2024년 이러닝시스템 운영 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국보건산업진흥원_의료기기산업 종합정보시스템(정보관리기관) 기능.xhtml ===
# 문단 3172, 표 144, 청크 3661개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국보건산업진흥원_의료기기산업 종합정보시스템(정보관리기관) 기능.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역.xhtml ===
# 문단 4965, 표 156, 청크 5519개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/BioIN_의료기기산업 종합정보시스템(정보관리기관) 기능개선 사업(2차).xhtml ===
# 문단 3172, 표 144, 청크 3661개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/BioIN_의료기기산업 종합정보시스템(정보관리기관) 기능개선 사업(2차).json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/부산관광공사_경영정보시스템 기능개선.xhtml ===
# 문단 3316, 표 136, 청크 3732개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/부산관광공사_경영정보시스템 기능개선.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/국가철도공단_철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역(변.xhtml ===
# 문단 2638, 표 103, 청크 2897개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/국가철도공단_철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역(변.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/고양도시관리공사_관산근린공원 다목적구장 홈페이지 및 회원 통합운영.xhtml ===
# 문단 3113, 표 135, 청크 3580개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/고양도시관리공사_관산근린공원 다목적구장 홈페이지 및 회원 통합운영.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국재정정보원_e나라도움 업무시스템 웹 접근성 컨설팅.xhtml ===
# 문단 2666, 표 84, 청크 3025개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국재정정보원_e나라도움 업무시스템 웹 접근성 컨설팅.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국생산기술연구원_2세대 전자조달시스템  기반구축사업.xhtml ===
# 문단 2905, 표 118, 청크 3387개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국생산기술연구원_2세대 전자조달시스템  기반구축사업.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.xhtml ===
# 문단 4503, 표 154, 청크 5087개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국지식재산보호원_IP-NAVI  해외지식재산센터 사업관리 시스템 기능개.xhtml ===
# 문단 2659, 표 89, 청크 2974개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국지식재산보호원_IP-NAVI  해외지식재산센터 사업관리 시스템 기능개.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/대한상공회의소_기업 재생에너지 지원센터 홈페이지 개편 및 시스템 고.xhtml ===
# 문단 3038, 표 128, 청크 3327개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/대한상공회의소_기업 재생에너지 지원센터 홈페이지 개편 및 시스템 고.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/인천광역시 동구_수도국산달동네박물관 전시해설 시스템 구축(협상에 .xhtml ===
# 문단 3455, 표 133, 청크 3876개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/인천광역시 동구_수도국산달동네박물관 전시해설 시스템 구축(협상에 .json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/대한장애인체육회_2025년 전국장애인체육대회 전산 및 시스템, 홈페이지 .xhtml ===
# 문단 2439, 표 122, 청크 2725개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/대한장애인체육회_2025년 전국장애인체육대회 전산 및 시스템, 홈페이지 .json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/인천광역시_도시계획위원회 통합관리시스템 구축용역.xhtml ===
# 문단 3050, 표 115, 청크 3400개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/인천광역시_도시계획위원회 통합관리시스템 구축용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/경희대학교_[입찰공고] 산학협력단 정보시스템 운영 용역업체 선정.xhtml ===
# 문단 1533, 표 54, 청크 1734개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/경희대학교_[입찰공고] 산학협력단 정보시스템 운영 용역업체 선정.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/국방과학연구소_대용량 자료전송시스템 고도화.xhtml ===
# 문단 2731, 표 68, 청크 3032개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/국방과학연구소_대용량 자료전송시스템 고도화.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/광주과학기술원_학사시스템 기능개선 사업.xhtml ===
# 문단 2437, 표 87, 청크 2720개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/광주과학기술원_학사시스템 기능개선 사업.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/국가과학기술지식정보서비스_통합정보시스템 고도화 용역.xhtml ===
# 문단 3135, 표 140, 청크 3497개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/국가과학기술지식정보서비스_통합정보시스템 고도화 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.xhtml ===
# 문단 4181, 표 158, 청크 4536개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 .xhtml ===
# 문단 2914, 표 145, 청크 3274개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 .json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/축산물품질평가원_축산물이력관리시스템 개선(정보화 사업).xhtml ===
# 문단 3477, 표 127, 청크 3810개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/축산물품질평가원_축산물이력관리시스템 개선(정보화 사업).json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자.xhtml ===
# 문단 2941, 표 132, 청크 3400개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국로봇산업진흥원_한국로봇산업진흥원 사업관리시스템 온라인평가 .xhtml ===
# 문단 2399, 표 79, 청크 2652개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국로봇산업진흥원_한국로봇산업진흥원 사업관리시스템 온라인평가 .json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/축산물품질평가원_꿀 품질평가 전산시스템 기능개선 사업.xhtml ===
# 문단 3334, 표 151, 청크 3823개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/축산물품질평가원_꿀 품질평가 전산시스템 기능개선 사업.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/중앙선거관리위원회_2025년도 행정정보시스템 위탁운영사업.xhtml ===
# 문단 3574, 표 168, 청크 4095개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/중앙선거관리위원회_2025년도 행정정보시스템 위탁운영사업.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/서영대학교 산학협력단_전문대학 혁신지원사업 서영대학교 차세대 교육.xhtml ===
# 문단 4179, 표 189, 청크 4685개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/서영대학교 산학협력단_전문대학 혁신지원사업 서영대학교 차세대 교육.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/남서울대학교_[혁신-국고] 남서울대학교 스마트 정보시스템 활성화(학사.xhtml ===
# 문단 2784, 표 130, 청크 3176개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/남서울대학교_[혁신-국고] 남서울대학교 스마트 정보시스템 활성화(학사.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역.xhtml ===
# 문단 2606, 표 108, 청크 3052개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/(사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .xhtml ===
# 문단 4975, 표 226, 청크 5544개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/(사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/(사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원시.xhtml ===
# 문단 2534, 표 107, 청크 2783개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/(사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원시.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국보육진흥원_연차별 자율 품질관리 시스템 기능개선.xhtml ===
# 문단 2928, 표 144, 청크 3313개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국보육진흥원_연차별 자율 품질관리 시스템 기능개선.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/재단법인 광주연구원_광주정책연구아카이브(GPA) 시스템 개발.xhtml ===
# 문단 3501, 표 141, 청크 3885개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/재단법인 광주연구원_광주정책연구아카이브(GPA) 시스템 개발.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/대한적십자사 의료원_적십자병원 병원정보 재해복구시스템 구축 용역 .xhtml ===
# 문단 2199, 표 80, 청크 2475개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/대한적십자사 의료원_적십자병원 병원정보 재해복구시스템 구축 용역 .json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국농어촌공사_네팔 수자원관리 정보화사업-Pilot 시스템 구축용역.xhtml ===
# 문단 3558, 표 80, 청크 3890개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국농어촌공사_네팔 수자원관리 정보화사업-Pilot 시스템 구축용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국발명진흥회 입찰공고_2024년 건설기술에 관한 특허·실용신안 활용실.xhtml ===
# 문단 3105, 표 149, 청크 3467개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국발명진흥회 입찰공고_2024년 건설기술에 관한 특허·실용신안 활용실.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/경기도사회서비스원_2024년 통합사회정보시스템 운영지원.xhtml ===
# 문단 3762, 표 121, 청크 4136개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/경기도사회서비스원_2024년 통합사회정보시스템 운영지원.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/인천광역시_인천일자리플랫폼 정보시스템 구축 ISP 수립용역.xhtml ===
# 문단 2441, 표 101, 청크 2753개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/인천광역시_인천일자리플랫폼 정보시스템 구축 ISP 수립용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/국방과학연구소_기록관리시스템 통합 활용 및 보안 환경 구축.xhtml ===
# 문단 2907, 표 111, 청크 3185개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/국방과학연구소_기록관리시스템 통합 활용 및 보안 환경 구축.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국해양조사협회_2024년 항해용 간행물 품질관리 업무보조 시스템 구축.xhtml ===
# 문단 2361, 표 77, 청크 2684개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국해양조사협회_2024년 항해용 간행물 품질관리 업무보조 시스템 구축.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국농어촌공사_아세안+3 식량안보정보시스템(AFSIS) 3단계 협력(캄보디아.xhtml ===
# 문단 4754, 표 174, 청크 5280개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국농어촌공사_아세안+3 식량안보정보시스템(AFSIS) 3단계 협력(캄보디아.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/국립인천해양박물관_국립인천해양박물관 해양자료관리시스템 구축 용.xhtml ===
# 문단 2799, 표 89, 청크 3144개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/국립인천해양박물관_국립인천해양박물관 해양자료관리시스템 구축 용.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센.xhtml ===
# 문단 4798, 표 179, 청크 5461개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/국민연금공단_사업장 사회보험료 지원 고시 개정에 따른 정보시스템 보.xhtml ===
# 문단 2640, 표 74, 청크 2902개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/국민연금공단_사업장 사회보험료 지원 고시 개정에 따른 정보시스템 보.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국수자원공사_용인 첨단 시스템반도체 국가산단 용수공급사업 타당성.xhtml ===
# 문단 1101, 표 12, 청크 1255개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국수자원공사_용인 첨단 시스템반도체 국가산단 용수공급사업 타당성.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스.xhtml ===
# 문단 2616, 표 105, 청크 2975개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/수협중앙회_강릉어선안전조업국 상황관제시스템 구축.xhtml ===
# 문단 2437, 표 118, 청크 2880개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/수협중앙회_강릉어선안전조업국 상황관제시스템 구축.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국철도공사 (용역)_예약발매시스템 개량 ISMP 용역.xhtml ===
# 문단 3337, 표 116, 청크 3712개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국철도공사 (용역)_예약발매시스템 개량 ISMP 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.xhtml ===
# 문단 3191, 표 136, 청크 3603개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국어촌어항공단_한국어촌어항공단 경영관리시스템(ERP·GW) 기능 고도.xhtml ===
# 문단 3648, 표 156, 청크 4111개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국어촌어항공단_한국어촌어항공단 경영관리시스템(ERP·GW) 기능 고도.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/을지대학교_을지대학교 비교과시스템 개발.xhtml ===
# 문단 3590, 표 104, 청크 4039개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/을지대학교_을지대학교 비교과시스템 개발.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/2025 구미 아시아육상경기선수권대회 조직위원회_2025 구미아시아육상경.xhtml ===
# 문단 2190, 표 91, 청크 2393개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/2025 구미 아시아육상경기선수권대회 조직위원회_2025 구미아시아육상경.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음.xhtml ===
# 문단 2451, 표 106, 청크 2713개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급).xhtml ===
# 문단 2698, 표 113, 청크 3087개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급).json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/서민금융진흥원_서민금융진흥원 서민금융 채팅 상담시스템 구축.xhtml ===
# 문단 3211, 표 142, 청크 3678개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/서민금융진흥원_서민금융진흥원 서민금융 채팅 상담시스템 구축.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국산업단지공단_산단 안전정보시스템 1차 구축 용역.xhtml ===
# 문단 4620, 표 171, 청크 5214개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국산업단지공단_산단 안전정보시스템 1차 구축 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/대검찰청_아태 사이버범죄 역량강화 허브(APC-HUB) 홈페이지 및 온라인 교.xhtml ===
# 문단 2145, 표 92, 청크 2459개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/대검찰청_아태 사이버범죄 역량강화 허브(APC-HUB) 홈페이지 및 온라인 교.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/광주과학기술원_실시간통합연구비관리시스템(RCMS)  연계 모듈 변경 사업.xhtml ===
# 문단 2861, 표 101, 청크 3216개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/광주과학기술원_실시간통합연구비관리시스템(RCMS)  연계 모듈 변경 사업.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/전북대학교_JST 공유대학(원) xAPI기반 LRS시스템 구축.xhtml ===
# 문단 2590, 표 103, 청크 2956개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/전북대학교_JST 공유대학(원) xAPI기반 LRS시스템 구축.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업.xhtml ===
# 문단 3677, 표 124, 청크 4164개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국철도공사 (용역)_[재공고][긴급][협상형]운행정보기록 자동분석시스.xhtml ===
# 문단 4491, 표 160, 청크 5227개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국철도공사 (용역)_[재공고][긴급][협상형]운행정보기록 자동분석시스.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/재단법인경기도일자리재단_2025년 통합접수시스템 운영.xhtml ===
# 문단 4539, 표 190, 청크 5119개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/재단법인경기도일자리재단_2025년 통합접수시스템 운영.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국농수산식품유통공사_농산물가격안정기금 정부예산회계연계시스템 .xhtml ===
# 문단 3016, 표 119, 청크 3379개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국농수산식품유통공사_농산물가격안정기금 정부예산회계연계시스템 .json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/서울특별시교육청_서울특별시교육청 지능정보화전략계획(ISP) 수립(2차) .xhtml ===
# 문단 2580, 표 123, 청크 3130개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/서울특별시교육청_서울특별시교육청 지능정보화전략계획(ISP) 수립(2차) .json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/나노종합기술원_스마트 팹 서비스 활용체계 구축관련 설비온라인 시스.xhtml ===
# 문단 3725, 표 122, 청크 4034개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/나노종합기술원_스마트 팹 서비스 활용체계 구축관련 설비온라인 시스.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국철도공사 (용역)_모바일오피스 시스템 고도화 용역(총체 및 1차).xhtml ===
# 문단 5784, 표 238, 청크 6579개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국철도공사 (용역)_모바일오피스 시스템 고도화 용역(총체 및 1차).json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/사단법인아시아물위원회사무국_우즈벡-키르기즈스탄 기후변화대응 스.xhtml ===
# 문단 2317, 표 68, 청크 2524개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/사단법인아시아물위원회사무국_우즈벡-키르기즈스탄 기후변화대응 스.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/파주도시관광공사_종량제봉투 판매관리 전산시스템 개선사업.xhtml ===
# 문단 4308, 표 155, 청크 4786개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/파주도시관광공사_종량제봉투 판매관리 전산시스템 개선사업.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/(재)예술경영지원센터_통합 정보시스템 구축 사전 컨설팅.xhtml ===
# 문단 2007, 표 95, 청크 2236개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/(재)예술경영지원센터_통합 정보시스템 구축 사전 컨설팅.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/세종테크노파크_세종테크노파크 인사정보 전산시스템 구축 용역 입찰공.xhtml ===
# 문단 2803, 표 112, 청크 3151개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/세종테크노파크_세종테크노파크 인사정보 전산시스템 구축 용역 입찰공.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국가스공사_[재공고]차세대 통합정보시스템(ERP) 구축.xhtml ===
# 문단 4636, 표 175, 청크 5074개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국가스공사_[재공고]차세대 통합정보시스템(ERP) 구축.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국건강가정진흥원_2025년 아이돌봄인력 인적성 검사 정보시스템 운영.xhtml ===
# 문단 2813, 표 128, 청크 3183개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국건강가정진흥원_2025년 아이돌봄인력 인적성 검사 정보시스템 운영.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/(사）한국대학스포츠협의회_KUSF 체육특기자 경기기록 관리시스템 개발.xhtml ===
# 문단 3763, 표 151, 청크 4187개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/(사）한국대학스포츠협의회_KUSF 체육특기자 경기기록 관리시스템 개발.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국산업인력공단_RFID기반 국가자격 시험 결과물 스마트 관리시스템 도.xhtml ===
# 문단 2313, 표 98, 청크 2648개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국산업인력공단_RFID기반 국가자격 시험 결과물 스마트 관리시스템 도.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국수자원공사_수도사업장 통합 사고분석솔루션 시범구축 용역.xhtml ===
# 문단 2447, 표 94, 청크 2733개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국수자원공사_수도사업장 통합 사고분석솔루션 시범구축 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국사회보장정보원_라오스 보건의료정보화 협력을 위한 사전타당성 조.xhtml ===
# 문단 1615, 표 66, 청크 1881개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국사회보장정보원_라오스 보건의료정보화 협력을 위한 사전타당성 조.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/그랜드코리아레저(주)_2024년도 GKL  그룹웨어 시스템 구축 용역.xhtml ===
# 문단 7622, 표 263, 청크 8429개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/그랜드코리아레저(주)_2024년도 GKL  그룹웨어 시스템 구축 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국전기안전공사_전기안전 관제시스템 보안 모듈 개발 용역.xhtml ===
# 문단 2396, 표 74, 청크 2655개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국전기안전공사_전기안전 관제시스템 보안 모듈 개발 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국수자원공사_건설통합시스템(CMS) 고도화.xhtml ===
# 문단 3110, 표 121, 청크 3543개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국수자원공사_건설통합시스템(CMS) 고도화.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국교육과정평가원_국가교육과정정보센터(NCIC) 시스템 운영 및 개선.xhtml ===
# 문단 2188, 표 75, 청크 2422개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국교육과정평가원_국가교육과정정보센터(NCIC) 시스템 운영 및 개선.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국원자력연구원_한국원자력연구원 선량평가시스템 고도화.xhtml ===
# 문단 1850, 표 87, 청크 2188개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국원자력연구원_한국원자력연구원 선량평가시스템 고도화.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/재단법인충북연구원_GIS통계 기반 재난안전데이터 분석ㆍ관리 시스템 구.xhtml ===
# 문단 2129, 표 94, 청크 2416개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/재단법인충북연구원_GIS통계 기반 재난안전데이터 분석ㆍ관리 시스템 구.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국수자원조사기술원_수문자료정보관리시스템(HDIMS) 재구축 용역(3단계.xhtml ===
# 문단 3542, 표 122, 청크 3980개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국수자원조사기술원_수문자료정보관리시스템(HDIMS) 재구축 용역(3단계.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국한의학연구원_통합정보시스템 고도화 용역.xhtml ===
# 문단 3135, 표 140, 청크 3497개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국한의학연구원_통합정보시스템 고도화 용역.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국수출입은행_(긴급) 모잠비크 마푸토 지능형교통시스템(ITS) 구축사업.xhtml ===
# 문단 3268, 표 91, 청크 3535개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국수출입은행_(긴급) 모잠비크 마푸토 지능형교통시스템(ITS) 구축사업.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.xhtml ===
# 문단 2114, 표 110, 청크 2426개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/재단법인스포츠윤리센터_스포츠윤리센터 LMS(학습지원시스템) 기능개선.xhtml ===
# 문단 3388, 표 139, 청크 3868개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/재단법인스포츠윤리센터_스포츠윤리센터 LMS(학습지원시스템) 기능개선.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/KOICA 전자조달_[긴급] [지문] [국제] 우즈베키스탄 열린 의정활동 상하원 .xhtml ===
# 문단 6111, 표 184, 청크 6940개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/KOICA 전자조달_[긴급] [지문] [국제] 우즈베키스탄 열린 의정활동 상하원 .json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/한국사학진흥재단_대학재정정보시스템(기본재산 및 기채 사후관리) 고.xhtml ===
# 문단 4590, 표 170, 청크 5195개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/한국사학진흥재단_대학재정정보시스템(기본재산 및 기채 사후관리) 고.json
#
# === 처리 중: ../data/processed/bydatapreprocessingbjs(0922)/all_xhtml/전북특별자치도 정읍시_정읍체육트레이닝센터 통합운영관리시스템 구.xhtml ===
# 문단 3959, 표 172, 청크 4578개 생성
# 💾 저장 완료: ../data/processed/bydatapreprocessingbjs(0922)/json/전북특별자치도 정읍시_정읍체육트레이닝센터 통합운영관리시스템 구.json

# %%
# import os
# import json
# from glob import glob

# def merge_all_json_chunks(input_dir, output_file):
#     """
#     input_dir 내 모든 JSON 파일을 읽어 하나의 리스트로 합치고 output_file로 저장
#     """
#     all_chunks = []

#     json_files = glob(os.path.join(input_dir, "*.json"))
#     print(f"🔹 총 {len(json_files)}개 JSON 파일 발견")

#     for jf in json_files:
#         with open(jf, "r", encoding="utf-8") as f:
#             data = json.load(f)
#             all_chunks.extend(data)

#     print(f"🔹 총 {len(all_chunks)}개 청크 합쳐짐")

#     os.makedirs(os.path.dirname(output_file), exist_ok=True)
#     with open(output_file, "w", encoding="utf-8") as f:
#         json.dump(all_chunks, f, ensure_ascii=False, indent=2)

#     print(f"✅ 모든 청크 저장 완료: {output_file}")


# if __name__ == "__main__":
#     input_json_dir = "/content/drive/MyDrive/코드잇/projectmission2/data/processed/bydatapreprocessingbjs(hwp5proc)/json"
#     output_json_file = "/content/drive/MyDrive/코드잇/projectmission2/data/processed/bydatapreprocessingbjs(hwp5proc)/json/all_chunks.json"

#     merge_all_json_chunks(input_json_dir, output_json_file)

# %%
import os
import json
from tqdm import tqdm
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.chains import RetrievalQA
from langchain_community.vectorstores import Chroma
from dotenv import load_dotenv
# from langchain_chroma import Chroma

# ==============================
# 환경 변수 & API 키
# ==============================
load_dotenv("../notebooks/api_key.env")
openai_api_key = os.getenv("OPENAI_API_KEY")

# ==============================
# JSON 청크 불러오기
# ==============================
json_folder = "../data/processed/bydatapreprocessingbjs(0922)/json"
all_chunks = []

json_files = [f for f in os.listdir(json_folder) if f.lower().endswith(".json")]
for jf in tqdm(json_files, desc="Loading JSON chunks"):
    with open(os.path.join(json_folder, jf), "r", encoding="utf-8") as f:
        chunks = json.load(f)
        file_prefix = os.path.splitext(jf)[0]
        for c in chunks:
            original_id = c.get("chunk_id", None)
            c["chunk_id"] = f"{file_prefix}_{original_id}"
        all_chunks.extend(chunks)

# ==============================
# 임베딩 생성 준비
# ==============================
embeddings = OpenAIEmbeddings(
    openai_api_key=openai_api_key,
    model="text-embedding-3-small"
)

# 메모리 내 Chroma 초기화
vectorstore = Chroma(embedding_function=embeddings, collection_name="hwp_chunks")

# ==============================
# 배치 단위 임베딩 처리
# ==============================
BATCH_SIZE = 100  # 필요에 따라 조절

for i in tqdm(range(0, len(all_chunks), BATCH_SIZE), desc="Vectorizing batches"):
    batch = all_chunks[i:i+BATCH_SIZE]
    texts = [c["content"] for c in batch]
    ids = [c.get("chunk_id", f"chunk_{i+j:06d}") for j, c in enumerate(batch)]
    vectorstore.add_texts(texts=texts, ids=ids)

print("✅ 메모리 내 Chroma DB 생성 완료")

# ==============================
# GPT-4.1-mini + RAG 연결
# ==============================
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 5})

llm = ChatOpenAI(
    model_name="gpt-4.1-mini",
    temperature=0
)

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True
)
# Out:
# Loading JSON chunks: 100%|██████████| 95/95 [00:01<00:00, 89.67it/s]
# Vectorizing batches: 100%|██████████| 3403/3403 [1:07:39<00:00,  1.19s/it]
# ✅ 메모리 내 Chroma DB 생성 완료

# %%
# from dotenv import load_dotenv
# import os
# import json
# from glob import glob
# from tqdm import tqdm

# # ❗ OpenAI, Chroma, LangChain import
# from langchain.vectorstores import Chroma
# from langchain_openai import OpenAIEmbeddings
# from langchain.chat_models import ChatOpenAI
# from langchain.chains import RetrievalQA

# # ==============================
# # 1️⃣ 환경 변수 & API 키
# # ==============================
# load_dotenv("../notebooks/api_key.env")

# openai_api_key = os.getenv("OPENAI_API_KEY")
# if not openai_api_key:
#     raise ValueError("❌ OPENAI_API_KEY가 없습니다!")

# # ==============================
# # 2️⃣ JSON 청크 불러오기
# # ==============================
# json_folder = "../data/processed/bydatapreprocessingbjs(0922)/json"

# all_chunks = []
# json_files = [f for f in os.listdir(json_folder) if f.lower().endswith(".json")]
# print(f"🔹 총 {len(json_files)}개 JSON 파일 발견")

# for jf in tqdm(json_files, desc="Loading JSON chunks"):
#     with open(os.path.join(json_folder, jf), "r", encoding="utf-8") as f:
#         chunks = json.load(f)
#         # 각 청크에 고유 ID 추가 (파일명_청크ID)
#         for c in chunks:
#             original_id = c.get("chunk_id", None)
#             file_prefix = os.path.splitext(jf)[0]
#             c["chunk_id"] = f"{file_prefix}_{original_id}"
#         all_chunks.extend(chunks)

# print(f"🔹 총 {len(all_chunks)}개 청크 합쳐짐")

# # ==============================
# # 3️⃣ 임베딩 생성 (DB 저장 및 배치 처리)
# # ==============================
# embeddings = OpenAIEmbeddings(
#     openai_api_key=openai_api_key,
#     model="text-embedding-3-small"  # 최신 임베딩 모델
# )

# persist_directory = "../data/processed/bydatapreprocessingbjs(0922)/chromaDB"
# os.makedirs(persist_directory, exist_ok=True)

# # 배치 크기 지정 (대용량 처리 안정화)
# BATCH_SIZE = 5000

# for i in tqdm(range(0, len(all_chunks), BATCH_SIZE), desc="Vectorizing batches"):
#     batch = all_chunks[i:i+BATCH_SIZE]
#     texts = [c["content"] for c in batch]
#     ids = [c.get("chunk_id", f"chunk_{i+j:06d}") for j, c in enumerate(batch)]
    
#     vectorstore = Chroma.from_texts(
#         texts=texts,
#         embedding=embeddings,
#         ids=ids,
#         persist_directory=persist_directory,
#         collection_name="hwp_chunks"  # 컬렉션 이름
#     )
#     vectorstore.persist()  # DB에 저장

# # ==============================
# # 4️⃣ GPT-4.1-mini + RAG 연결
# # ==============================
# retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k":5})

# llm = ChatOpenAI(
#     model_name="gpt-4.1-mini",
#     openai_api_key=openai_api_key,
#     temperature=0
# )

# qa_chain = RetrievalQA.from_chain_type(
#     llm=llm,
#     chain_type="stuff",
#     retriever=retriever,
#     return_source_documents=True
# )

# %%
# ==============================
# 5️⃣ 질문 예시
# ==============================
query = "'경기도'가 제목에 들어간 제안요청서를 알려줘."
result = qa_chain(query)
print("=== Answer ===")
print(result['result'])
print("\n=== Source Docs ===")
for doc in result['source_documents']:
    print("-", doc.metadata.get("source", "unknown"))
# Out:
# /tmp/ipykernel_109205/1881171153.py:5: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = qa_chain(query)
# === Answer ===
# 제공된 정보에는 '경기도'가 제목에 들어간 제안요청서에 대한 구체적인 내용이 없습니다. 추가 정보를 주시면 더 도와드릴 수 있습니다.
#
# === Source Docs ===
# - unknown
# - unknown
# - unknown
# - unknown
# - unknown

# %%
# import shutil

# # 삭제할 폴더 경로를 지정하세요.
# folder_path = '/content/drive/MyDrive/코드잇/projectmission2/data/processed/bydatapreprocessingbjs(hwp5proc)/vectorstore'
# try:
#     shutil.rmtree(folder_path)
#     print(f"'{folder_path}' 폴더와 모든 내용이 성공적으로 삭제되었습니다.")
# except OSError as e:
#     print(f"오류: {e.strerror} - {e.filename}")
